# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series

# %% [markdown]
# The first main data type we will learn about for pandas is the Series data type. Let's import Pandas and explore the Series object.
#
# A Series is very similar to a NumPy array (in fact it is built on top of the NumPy array object). What differentiates the NumPy array from a Series, is that a Series can have axis labels, meaning it can be indexed by a label, instead of just a number location. It also doesn't need to hold numeric data, it can hold any arbitrary Python Object.
#
# Let's explore this concept through some examples:

# %%
# help(pd.Series)

# %%
myindex = ['amir', 'hosein', 'ali']
mydata = [12, 18, 20]

# %%
my_ser = pd.Series(data=mydata)

# %%
my_ser
# Out:
# 0    12
# 1    18
# 2    20
# dtype: int64

# %%
my_ser = pd.Series(data=mydata, index=myindex)

# %%
my_ser
# Out:
# amir      12
# hosein    18
# ali       20
# dtype: int64

# %% [markdown]
# # DataFrames
#
# Throughout the course, most of our data exploration will be done with DataFrames. DataFrames are an extremely powerful tool and a natural extension of the Pandas Series. By definition all a DataFrame is:
#
# **A Pandas DataFrame consists of multiple Pandas Series that share index values.**

# %%
# help(pd.DataFrame)

# %%
myindex
# Out:
# ['amir', 'hosein', 'ali']

# %%
mydata
# Out:
# [12, 18, 20]

# %%
df = pd.DataFrame(data=mydata)

# %%
df
# Out:
#     0
# 0  12
# 1  18
# 2  20

# %%
df = pd.DataFrame(data=mydata, index=myindex)

# %%
df
# Out:
#          0
# amir    12
# hosein  18
# ali     20

# %% [markdown]
# # Reading a .csv file for a DataFrame
#
# ----
#
# ## NOTE: We will go over all kinds of data inputs and outputs (.html, .csv, .xlxs , etc...) later on in the course! For now we just need to read in a simple .csv file.
#
# ----

# %% [markdown]
# conda install xlrd
# conda install openpyxl

# %%
df = pd.read_csv('tips.csv')

# %%
# file_path = "C:/Users/Amir/Desktop/python/tips.csv"
# df = pd.read_csv(file_path)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 11

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.tail(4)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df['smoker']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: object

# %%
df['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\envs\project_env\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\envs\project_env\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\envs\project_env\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df['name']
#
# File C:\ProgramData\Anaconda3\envs\project_env\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File C:\ProgramData\Anaconda3\envs\project_env\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'name'

# %%
df2 = df[['total_bill', 'tip']]

# %%
df2
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
df['tip_percentage'] = 100 * df['tip'] / df['total_bill']

# %%
df['tip_percentage']
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Name: tip_percentage, Length: 244, dtype: float64

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159

# %%
df['tip_percentage'] = np.round(df['tip_percentage'], 2)

# %%
df['tip_percentage']
# Out:
# 0       5.94
# 1      16.05
# 2      16.66
# 3      13.98
# 4      14.68
#        ...
# 239    20.39
# 240     7.36
# 241     8.82
# 242     9.82
# 243    15.97
# Name: tip_percentage, Length: 244, dtype: float64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4        Tonya Carter  4832732618637221    Sun2251           14.68

# %%
# df = df.drop('tip_percentage', axis=1)

# %%
df.drop("tip_percentage", axis=1, inplace=True)

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.set_index("Payment ID", inplace=True)

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994
# 4              6.15        Tonya Carter  4832732618637221

# %%
gorgan_temp = pd.read_csv('gorgan.csv')

# %%
gorgan_temp.head()
# Out:
#    YEAR     JAN     FEB     MAR     APR     MAY     JUN     JUL     AUG  \
# 0  1952  999.90  999.90  999.90  999.90  999.90  999.90  999.90  999.90
# 1  1953    7.83    9.98    7.27   10.67  999.90  999.90   25.28   26.58
# 2  1954  999.90  999.90  999.90   10.73   20.58   24.88   27.83   27.38
# 3  1955    7.23   11.63    9.08   13.63   19.38   23.47   27.38   27.13
# 4  1956    7.58    6.63    6.83   14.08   16.88   22.43   24.33   26.03
#
#       SEP     OCT     NOV     DEC   D-J-F   M-A-M   J-J-A   S-O-N  metANN
# 0  999.90  999.90  999.90    7.27  999.90  999.90  999.90  999.90  999.90
# 1   22.22   16.03  999.90  999.90    8.36   11.62   25.20   16.32   15.37
# 2   24.63   19.72   13.18    8.38  999.90   13.15   26.70   19.18   16.60
# 3   23.22   18.42   13.42    8.88    9.08   14.03   25.99   18.35   16.86
# 4   21.03   16.58   12.78    7.27    7.70   12.60   24.26   16.80   15.34

# %%
gorgan_temp.describe()
# Out:
#              YEAR         JAN         FEB         MAR         APR         MAY  \
# count    72.00000   72.000000   72.000000   72.000000   72.000000   72.000000
# mean   1987.50000  144.443472  145.082222  161.092917  151.407917  183.432917
# std      20.92845  345.975977  345.717267  358.704038  343.157429  367.699647
# min    1952.00000    1.270000    1.520000    5.440000   10.670000   16.870000
# 25%    1969.75000    5.857500    6.235000    8.857500   13.487500   19.440000
# 50%    1987.50000    7.175000    8.005000   10.615000   15.000000   20.540000
# 75%    2005.25000    8.582500    9.145000   11.982500   16.370000   21.937500
# max    2023.00000  999.900000  999.900000  999.900000  999.900000  999.900000
#
#               JUN         JUL         AUG         SEP         OCT         NOV  \
# count   72.000000   72.000000   72.000000   72.000000   72.000000   72.000000
# mean   173.535833  175.426806  148.339722  145.615278  140.869028  135.882500
# std    353.381865  352.572665  324.120861  325.157800  326.965528  328.863793
# min     21.210000   23.870000   24.020000   20.320000   14.670000    7.540000
# 25%     23.610000   25.847500   25.832500   22.460000   17.080000   11.575000
# 50%     24.845000   26.965000   26.935000   23.855000   18.340000   13.190000
# 75%     26.345000   28.472500   28.317500   25.097500   19.825000   14.230000
# max    999.900000  999.900000  999.900000  999.900000  999.900000  999.900000
#
#               DEC       D-J-F       M-A-M       J-J-A       S-O-N      metANN
# count   72.000000   72.000000   72.000000   72.000000   72.000000   72.000000
# mean   159.836250  131.427500  151.615417  161.245278  140.786250  166.783750
# std    359.239521  330.557581  343.072031  339.177621  326.995048  356.266758
# min      4.520000    3.850000   11.620000   23.890000   15.700000   14.210000
# 25%      7.557500    6.827500   14.235000   25.175000   17.375000   16.042500
# 50%      8.755000    7.835000   14.980000   26.190000   18.325000   16.745000
# 75%      9.982500    8.692500   16.115000   27.607500   19.362500   17.702500
# max    999.900000  999.900000  999.900000  999.900000  999.900000  999.900000

# %%
gorgan_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   YEAR    72 non-null     int64
#  1   JAN     72 non-null     float64
#  2   FEB     72 non-null     float64
#  3   MAR     72 non-null     float64
#  4   APR     72 non-null     float64
#  5   MAY     72 non-null     float64
#  6   JUN     72 non-null     float64
#  7   JUL     72 non-null     float64
#  8   AUG     72 non-null     float64
#  9   SEP     72 non-null     float64
#  10  OCT     72 non-null     float64
#  11  NOV     72 non-null     float64
#  12  DEC     72 non-null     float64
#  13  D-J-F   72 non-null     float64
#  14  M-A-M   72 non-null     float64
#  15  J-J-A   72 non-null     float64
#  16  S-O-N   72 non-null     float64
#  17  metANN  72 non-null     float64
# dtypes: float64(17), int64(1)
# memory usage: 10.2 KB

# %%
df.head(1)
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410

# %%
df.iloc[122]
# Out:
# Payment ID                 Thur3579
# total_bill                    14.26
# tip                             2.5
# sex                            Male
# smoker                           No
# day                            Thur
# time                          Lunch
# size                              2
# price_per_person               7.13
# Payer Name             Perry Garcia
# CC Number           180034646320219
# Name: 122, dtype: object

# %%
df.iloc[:4]
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994

# %%
df.set_index("Payment ID", inplace=True)

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %% [markdown]
# # Conditional Filtering

# %%
df.reset_index(inplace=True)

# %%
df.head(2)
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230

# %%
bool_series = df['total_bill'] > 30

# %%
df[bool_series]
# Out:
#     Payment ID  total_bill    tip     sex smoker   day    time  size  \
# 11     Sun6686       35.26   5.00  Female     No   Sun  Dinner     4
# 23      Sat239       39.42   7.58    Male     No   Sat  Dinner     4
# 39     Sat6373       31.27   5.00    Male     No   Sat  Dinner     3
# 44     Sun2274       30.40   5.60    Male     No   Sun  Dinner     4
# 47     Sun9677       32.40   6.00    Male     No   Sun  Dinner     4
# 52     Sun6165       34.81   5.20  Female     No   Sun  Dinner     4
# 56     Sat8903       38.01   3.00    Male    Yes   Sat  Dinner     4
# 59     Sat8139       48.27   6.73    Male     No   Sat  Dinner     4
# 83    Thur8801       32.68   5.00    Male    Yes  Thur   Lunch     2
# 85    Thur7972       34.83   5.17  Female     No  Thur   Lunch     4
# 95     Fri9628       40.17   4.73    Male    Yes   Fri  Dinner     4
# 102    Sat6240       44.30   2.50  Female    Yes   Sat  Dinner     3
# 112     Sun591       38.07   4.00    Male     No   Sun  Dinner     3
# 141   Thur1025       34.30   6.70    Male     No  Thur   Lunch     6
# 142   Thur3621       41.19   5.00    Male     No  Thur   Lunch     5
# 156    Sun7518       48.17   5.00    Male     No   Sun  Dinner     6
# 167    Sun3719       31.71   4.50    Male     No   Sun  Dinner     4
# 170    Sat1954       50.81  10.00    Male    Yes   Sat  Dinner     3
# 173    Sun9335       31.85   3.18    Male    Yes   Sun  Dinner     2
# 175    Sun5109       32.90   3.11    Male    Yes   Sun  Dinner     2
# 179    Sun9851       34.63   3.55    Male    Yes   Sun  Dinner     2
# 180    Sun7544       34.65   3.68    Male    Yes   Sun  Dinner     4
# 182    Sun2337       45.35   3.50    Male    Yes   Sun  Dinner     3
# 184    Sun5140       40.55   3.00    Male    Yes   Sun  Dinner     2
# 187    Sun9987       30.46   2.00    Male    Yes   Sun  Dinner     5
# 197   Thur9313       43.11   5.00  Female    Yes  Thur   Lunch     4
# 207    Sat4505       38.73   3.00    Male    Yes   Sat  Dinner     4
# 210    Sat8361       30.06   2.00    Male    Yes   Sat  Dinner     3
# 212    Sat4590       48.33   9.00    Male     No   Sat  Dinner     4
# 219    Sat8863       30.14   3.09  Female    Yes   Sat  Dinner     4
# 237    Sat2929       32.83   1.17    Male    Yes   Sat  Dinner     2
# 238    Sat9777       35.83   4.67  Female     No   Sat  Dinner     3
#
#      price_per_person             Payer Name         CC Number
# 11               8.82           Diane Macias  4577817359320969
# 23               9.86         Lance Peterson  3542584061609808
# 39              10.42      Mr. Brandon Berry  6011525851069856
# 44               7.60            Todd Cooper      503846761263
# 47               8.10           James Barnes  3552002592874186
# 52               8.70           Emily Daniel  4291280793094374
# 56               9.50  James Christensen DDS   349793629453226
# 59              12.07            Brian Ortiz  6596453823950595
# 83              16.34          Daniel Murphy  5356177501009133
# 85               8.71            Shawna Cook  6011787464177340
# 95              10.04          Aaron Bentley   180026611638690
# 102             14.77          Heather Cohen   379771118886604
# 112             12.69             Jeff Lopez  3572865915176463
# 141              5.72         Steven Carlson  3526515703718508
# 142              8.24           Eric Andrews  4356531761046453
# 156              8.03          Ryan Gonzales  3523151482063321
# 167              7.93         Michael Lawson  3566285921227119
# 170             16.94          Gregory Clark  5473850968388236
# 173             15.92            Scott Perez  3577115550328507
# 175             16.45        Nathan Reynolds   370307040837149
# 179             17.32           Brian Bailey   346656312114848
# 180              8.66       James Hebert DDS      676168737648
# 182             15.12           Jose Parsons  4112207559459910
# 184             20.27            Stephen Cox  3547798222044029
# 187              6.09          David Barrett  4792882899700988
# 197             10.78            Brooke Soto  5544902205760175
# 207              9.68          Ricky Ramirez   347817964484033
# 210             10.02          Shawn Mendoza    30184049218122
# 212             12.08        Alex Williamson      676218815212
# 219              7.54           Shelby House      502097403252
# 237             16.42           Thomas Brown  4284722681265508
# 238             11.94         Kimberly Crane      676184013727

# %%
df[df['smoker'] == 'No']
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 235    Sat4615       10.07  1.25    Male     No   Sat  Dinner     2
# 238    Sat9777       35.83  4.67  Female     No   Sat  Dinner     3
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# 0                8.49  Christy Cunningham  3560325168603410
# 1                3.45      Douglas Tucker  4478071379779230
# 2                7.00      Travis Walters  6011812112971322
# 3               11.84    Nathaniel Harris  4676137647685994
# 4                6.15        Tonya Carter  4832732618637221
# ..                ...                 ...               ...
# 235              5.04       Sean Gonzalez  3534021246117605
# 238             11.94      Kimberly Crane      676184013727
# 239              9.68       Michael Avila  5296068606052842
# 242              8.91        Dennis Dixon     4375220550950
# 243              9.39     Michelle Hardin  3511451626698139
#
# [151 rows x 11 columns]

# %%
df[(df['smoker'] == 'No') & (df['total_bill'] > 30)]
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 11     Sun6686       35.26  5.00  Female     No   Sun  Dinner     4
# 23      Sat239       39.42  7.58    Male     No   Sat  Dinner     4
# 39     Sat6373       31.27  5.00    Male     No   Sat  Dinner     3
# 44     Sun2274       30.40  5.60    Male     No   Sun  Dinner     4
# 47     Sun9677       32.40  6.00    Male     No   Sun  Dinner     4
# 52     Sun6165       34.81  5.20  Female     No   Sun  Dinner     4
# 59     Sat8139       48.27  6.73    Male     No   Sat  Dinner     4
# 85    Thur7972       34.83  5.17  Female     No  Thur   Lunch     4
# 112     Sun591       38.07  4.00    Male     No   Sun  Dinner     3
# 141   Thur1025       34.30  6.70    Male     No  Thur   Lunch     6
# 142   Thur3621       41.19  5.00    Male     No  Thur   Lunch     5
# 156    Sun7518       48.17  5.00    Male     No   Sun  Dinner     6
# 167    Sun3719       31.71  4.50    Male     No   Sun  Dinner     4
# 212    Sat4590       48.33  9.00    Male     No   Sat  Dinner     4
# 238    Sat9777       35.83  4.67  Female     No   Sat  Dinner     3
#
#      price_per_person         Payer Name         CC Number
# 11               8.82       Diane Macias  4577817359320969
# 23               9.86     Lance Peterson  3542584061609808
# 39              10.42  Mr. Brandon Berry  6011525851069856
# 44               7.60        Todd Cooper      503846761263
# 47               8.10       James Barnes  3552002592874186
# 52               8.70       Emily Daniel  4291280793094374
# 59              12.07        Brian Ortiz  6596453823950595
# 85               8.71        Shawna Cook  6011787464177340
# 112             12.69         Jeff Lopez  3572865915176463
# 141              5.72     Steven Carlson  3526515703718508
# 142              8.24       Eric Andrews  4356531761046453
# 156              8.03      Ryan Gonzales  3523151482063321
# 167              7.93     Michael Lawson  3566285921227119
# 212             12.08    Alex Williamson      676218815212
# 238             11.94     Kimberly Crane      676184013727

# %%
df[(df['smoker'] == 'No') & (df['total_bill'] > 30)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 11 to 238
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Payment ID        15 non-null     object
#  1   total_bill        15 non-null     float64
#  2   tip               15 non-null     float64
#  3   sex               15 non-null     object
#  4   smoker            15 non-null     object
#  5   day               15 non-null     object
#  6   time              15 non-null     object
#  7   size              15 non-null     int64
#  8   price_per_person  15 non-null     float64
#  9   Payer Name        15 non-null     object
#  10  CC Number         15 non-null     int64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 1.4+ KB

# %%
df[(df['total_bill'] > 30) & ~(df['sex']=='Male')]
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 11     Sun6686       35.26  5.00  Female     No   Sun  Dinner     4
# 52     Sun6165       34.81  5.20  Female     No   Sun  Dinner     4
# 85    Thur7972       34.83  5.17  Female     No  Thur   Lunch     4
# 102    Sat6240       44.30  2.50  Female    Yes   Sat  Dinner     3
# 197   Thur9313       43.11  5.00  Female    Yes  Thur   Lunch     4
# 219    Sat8863       30.14  3.09  Female    Yes   Sat  Dinner     4
# 238    Sat9777       35.83  4.67  Female     No   Sat  Dinner     3
#
#      price_per_person      Payer Name         CC Number
# 11               8.82    Diane Macias  4577817359320969
# 52               8.70    Emily Daniel  4291280793094374
# 85               8.71     Shawna Cook  6011787464177340
# 102             14.77   Heather Cohen   379771118886604
# 197             10.78     Brooke Soto  5544902205760175
# 219              7.54    Shelby House      502097403252
# 238             11.94  Kimberly Crane      676184013727

# %%
df[(df['total_bill'] > 30) & (df['sex'] != 'Male')]
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 11     Sun6686       35.26  5.00  Female     No   Sun  Dinner     4
# 52     Sun6165       34.81  5.20  Female     No   Sun  Dinner     4
# 85    Thur7972       34.83  5.17  Female     No  Thur   Lunch     4
# 102    Sat6240       44.30  2.50  Female    Yes   Sat  Dinner     3
# 197   Thur9313       43.11  5.00  Female    Yes  Thur   Lunch     4
# 219    Sat8863       30.14  3.09  Female    Yes   Sat  Dinner     4
# 238    Sat9777       35.83  4.67  Female     No   Sat  Dinner     3
#
#      price_per_person      Payer Name         CC Number
# 11               8.82    Diane Macias  4577817359320969
# 52               8.70    Emily Daniel  4291280793094374
# 85               8.71     Shawna Cook  6011787464177340
# 102             14.77   Heather Cohen   379771118886604
# 197             10.78     Brooke Soto  5544902205760175
# 219              7.54    Shelby House      502097403252
# 238             11.94  Kimberly Crane      676184013727

# %%
df[(df['day'] == 'Sun') | (df['day'] == 'Sat')]
# Out:
#     Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
# ..         ...         ...   ...     ...    ...  ...     ...   ...
# 238    Sat9777       35.83  4.67  Female     No  Sat  Dinner     3
# 239    Sat2657       29.03  5.92    Male     No  Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No  Sat  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# 0                8.49  Christy Cunningham  3560325168603410
# 1                3.45      Douglas Tucker  4478071379779230
# 2                7.00      Travis Walters  6011812112971322
# 3               11.84    Nathaniel Harris  4676137647685994
# 4                6.15        Tonya Carter  4832732618637221
# ..                ...                 ...               ...
# 238             11.94      Kimberly Crane      676184013727
# 239              9.68       Michael Avila  5296068606052842
# 240             13.59      Monica Sanders  3506806155565404
# 241             11.34          Keith Wong  6011891618747196
# 242              8.91        Dennis Dixon     4375220550950
#
# [163 rows x 11 columns]

# %%
w = df[df['day'].isin(['Sat', 'Sun'])]

# %%
w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163 entries, 0 to 242
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Payment ID        163 non-null    object
#  1   total_bill        163 non-null    float64
#  2   tip               163 non-null    float64
#  3   sex               163 non-null    object
#  4   smoker            163 non-null    object
#  5   day               163 non-null    object
#  6   time              163 non-null    object
#  7   size              163 non-null    int64
#  8   price_per_person  163 non-null    float64
#  9   Payer Name        163 non-null    object
#  10  CC Number         163 non-null    int64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 15.3+ KB
